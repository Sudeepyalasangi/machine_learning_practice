# %%
x = [1, 2, 3, 4, 5]
y = [3, 4, 2, 4, 5]
y_pridict = [2.8, 3.2, 3.6, 4, 4.4,]

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
plt.scatter(x, y, marker="*")
plt.plot(x, y_pridict)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\CSV files\HousePricePrediction.csv")

# %%
df.head()
# Out:
#      Town  Area    Price
# 0  Mumbai  2000  5500000
# 1  Mumbai  2100  5530000
# 2  Mumbai  2200  5560000
# 3  Mumbai  2300  5590000
# 4  Mumbai  2400  5620000

# %%
df.tail()
# Out:
#      Town  Area    Price
# 34   Pune  5400  6520000
# 35  Delhi  5500  6550000
# 36  Delhi  5600  6580000
# 37  Delhi  5700  6610000
# 38  Delhi  5800  6640000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Town    39 non-null     object
#  1   Area    39 non-null     int64
#  2   Price   39 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.0+ KB

# %%
df.shape
# Out:
# (39, 3)

# %%
df.isnull().sum()
# Out:
# Town     0
# Area     0
# Price    0
# dtype: int64

# %% [markdown]
# #pip install scikit_learn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(df[['Area']],df['Price'])
# Out:
# LinearRegression()

# %%
y_pred = model.predict(df[['Area']])
y_pred
# Out:
# array([5500000., 5530000., 5560000., 5590000., 5620000., 5650000.,
#        5680000., 5710000., 5740000., 5770000., 5800000., 5830000.,
#        5860000., 5890000., 5920000., 5950000., 5980000., 6010000.,
#        6040000., 6070000., 6100000., 6130000., 6160000., 6190000.,
#        6220000., 6250000., 6280000., 6310000., 6340000., 6370000.,
#        6400000., 6430000., 6460000., 6490000., 6520000., 6550000.,
#        6580000., 6610000., 6640000.])

# %%
plt.scatter(df.Area,df.Price)
plt.plot(df.Area,y_pred, color='r')
plt.show()

# %%
model.coef_
# Out:
# array([300.])

# %%
model.intercept_
# Out:
# np.float64(4900000.000000001)

# %% [markdown]
# Mean Absolute erroe(MAE)
# Mean square error (MSE)
# Mean Absolute percentage error(MAPE)
# Mean percentage error(MPE)

# %%
from sklearn.metrics import r2_score

# %%
df.head()
# Out:
#      Town  Area    Price
# 0  Mumbai  2000  5500000
# 1  Mumbai  2100  5530000
# 2  Mumbai  2200  5560000
# 3  Mumbai  2300  5590000
# 4  Mumbai  2400  5620000

# %%
r2_score(df['Price'],y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(df['Price'],y_pred)
# Out:
# 8.896017825522087e-20

# %%
model.predict([[5500]])
# Out:
# array([6550000.])

# %%
model.score(df[['Area']],df.Price)
# Out:
# 1.0

# %%
age = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]

# %%
speed = [99, 86, 87,88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# %%
len(age)
# Out:
# 13

# %%
len(speed)
# Out:
# 13

# %%
plt.scatter(age,speed)
plt.show()

# %%
from scipy import stats

# %%
 slop, intercept, r, p, stderr = stats.linregress(age,speed)

# %%
slop
# Out:
# np.float64(-1.751287711552612)

# %%
intercept
# Out:
# np.float64(103.10596026490066)

# %%
r
# Out:
# np.float64(-0.758591524376155)

# %%
p
# Out:
# np.float64(0.0026468739224561064)

# %%
stderr
# Out:
# np.float64(0.45353615760774213)

# %%
age
# Out:
# [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]

# %%
def prediction(x):
    return slop*x +intercept

# %%
#prediction(5)

# %%
y_pred =list(map(prediction,age))

# %%
y_pred
# Out:
# [np.float64(94.3495217071376),
#  np.float64(90.84694628403237),
#  np.float64(89.09565857247976),
#  np.float64(90.84694628403237),
#  np.float64(99.60338484179543),
#  np.float64(73.33406916850626),
#  np.float64(99.60338484179543),
#  np.float64(87.34437086092716),
#  np.float64(96.1008094186902),
#  np.float64(83.84179543782193),
#  np.float64(82.09050772626932),
#  np.float64(87.34437086092716),
#  np.float64(92.59823399558499)]

# %%
age
# Out:
# [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]

# %%
speed
# Out:
# [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# %%
y_pred
# Out:
# [np.float64(94.3495217071376),
#  np.float64(90.84694628403237),
#  np.float64(89.09565857247976),
#  np.float64(90.84694628403237),
#  np.float64(99.60338484179543),
#  np.float64(73.33406916850626),
#  np.float64(99.60338484179543),
#  np.float64(87.34437086092716),
#  np.float64(96.1008094186902),
#  np.float64(83.84179543782193),
#  np.float64(82.09050772626932),
#  np.float64(87.34437086092716),
#  np.float64(92.59823399558499)]

# %%
plt.scatter(age,speed)
plt.plot(age,y_pred)
plt.show()

# %%
#pip install seaborn

# %%
import seaborn as sns

# %%
#sns.displot(y_pred)
