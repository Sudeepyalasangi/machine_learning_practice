# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df =  pd.read_csv("D:\CSV files\scale.csv")

# %%
df.head()
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo     1.0     790   99
# 1  Mitsubishi  Space Star     1.2    1160   95
# 2       Skoda      Citigo     1.0     929   95
# 3        Fiat         500     0.9     865   90
# 4        Mini      Cooper     1.5    1140  105

# %%
df.tail()
# Out:
#          Car   Model  Volume  Weight  CO2
# 31     Volvo    XC70     2.0    1746  117
# 32      Ford   B-Max     1.6    1235  104
# 33       BMW     216     1.6    1390  108
# 34      Opel  Zafira     1.6    1405  109
# 35  Mercedes     SLK     2.5    1395  120

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Car     36 non-null     object
#  1   Model   36 non-null     object
#  2   Volume  36 non-null     float64
#  3   Weight  36 non-null     int64
#  4   CO2     36 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.5+ KB

# %%
df.shape
# Out:
# (36, 5)

# %%
df.isnull().sum()
# Out:
# Car       0
# Model     0
# Volume    0
# Weight    0
# CO2       0
# dtype: int64

# %%
df.describe()
# Out:
#           Volume       Weight         CO2
# count  36.000000    36.000000   36.000000
# mean    1.611111  1292.277778  102.027778
# std     0.388975   242.123889    7.454571
# min     0.900000   790.000000   90.000000
# 25%     1.475000  1117.250000   97.750000
# 50%     1.600000  1329.000000   99.000000
# 75%     2.000000  1418.250000  105.000000
# max     2.500000  1746.000000  120.000000

# %%
x = df[["Volume","Weight"]]

# %%
x.head()
# Out:
#    Volume  Weight
# 0     1.0     790
# 1     1.2    1160
# 2     1.0     929
# 3     0.9     865
# 4     1.5    1140

# %%
y = df.CO2

# %%
y.head()
# Out:
# 0     99
# 1     95
# 2     95
# 3     90
# 4    105
# Name: CO2, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
model = MinMaxScaler()

# %%
X= model.fit_transform(x)

# %%
model
# Out:
# MinMaxScaler()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([12.48841204,  7.21870559])

# %%
model.intercept_
# Out:
# np.float64(92.68469940966934)

# %%
new = model.transform([[1.5, 850]])
new
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 new = model.transform([[1.5, 850]])
#       2 new
#
# AttributeError: 'LinearRegression' object has no attribute 'transform'

# %%
model.predict(new)

# %%
model.score(scaler_x,y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

# %%
scalex = scale.fit_transform(x)

# %%
scalex

# %%
model.fit(scalex, y)

# %%
new = scale.transform([[1.3,356]])

# %%
new

# %%
model.predict(new)
